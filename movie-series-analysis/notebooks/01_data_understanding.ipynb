# %%
import pandas as pd

#Loading dataframe:
df = pd.read_csv('C:\\Users\\pedro\\OneDrive\\Desktop\\Reccomendation_System\\movie-series-analysis\\data\\raw\\raw' \
'_titles.csv')

#--------------------Initial Inspection-----------------------------------------------------#


lines = df.shape[0]
columns = df.shape[1] # verifying dimensions of the data frame
print(f"{lines} lines, {columns} columns")

df.info() # verifying general structure of the data frame

print(df.head()) # inspecting first lines of the data frame

print(df.dtypes) # identifying data frame types

print(df.columns) #
# Out:
# 5806 lines, 12 columns
# <class 'pandas.DataFrame'>
# RangeIndex: 5806 entries, 0 to 5805
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5806 non-null   str
#  1   title                 5805 non-null   str
#  2   type                  5806 non-null   str
#  3   release_year          5806 non-null   int64
#  4   age_certification     3196 non-null   str
#  5   runtime               5806 non-null   int64
#  6   genres                5806 non-null   str
#  7   production_countries  5806 non-null   str
#  8   seasons               2047 non-null   float64
#  9   imdb_id               5362 non-null   str
#  10  imdb_score            5283 non-null   float64
#  11  imdb_votes            5267 non-null   float64
# dtypes: float64(3), int64(2), str(7)
# memory usage: 544.4 KB
#          id                                title   type  release_year  \
# ...

# %%
import pandas as pd

#Loading dataframe:
df = pd.read_csv('C:\\Users\\pedro\\OneDrive\\Desktop\\Reccomendation_System\\movie-series-analysis\\data\\raw\\raw' \
'_titles.csv')

#--------------------Null values treatment-------------------------------------------------#

df.isnull().sum()

(df.isnull().sum() / len(df)) * 100 # calculating percentage of null values in each column
# Out:
#              id title   type  release_year age_certification  runtime genres  \
# 1805  tm1063792   NaN  MOVIE          2015               NaN       11     []
#
#      production_countries  seasons    imdb_id  imdb_score  imdb_votes
# 1805                   []      NaN  tt4661188         NaN         NaN

# %%
import pandas as pd

#Loading dataframe:
df = pd.read_csv('C:\\Users\\pedro\\OneDrive\\Desktop\\Reccomendation_System\\movie-series-analysis\\data\\raw\\raw' \
'_titles.csv')
    
df.median(numeric_only=True)
# Out:
# release_year    2018.0
# runtime           84.0
# seasons            1.0
# imdb_score         6.6
# imdb_votes      2279.0
# dtype: float64

# %%
import pandas as pd

#Loading dataframe:
df = pd.read_csv('C:\\Users\\pedro\\OneDrive\\Desktop\\Reccomendation_System\\movie-series-analysis\\data\\raw\\raw' \
'_titles.csv')

df.mean(numeric_only=True)
# Out:
# release_year     2016.013434
# runtime            77.643989
# seasons             2.165608
# imdb_score          6.533447
# imdb_votes      23407.194988
# dtype: float64

# %%
import pandas as pd

#Loading clean dataframe:
df = pd.read_csv('C:\\Users\\pedro\\OneDrive\\Desktop\\Reccomendation_System\\movie-series-analysis\\data\\processed\\clean_titles.csv')

print("\nMean:")
print(df.mean(numeric_only=True))


print("\nMedian:")
print(df.median(numeric_only=True))

print("\nPercentage of Missing Values:")
print((df.isnull().sum() / len(df)) * 100)
# Out:
# Mean:
# release_year     2014.222785
# runtime            91.274684
# seasons             3.232704
# imdb_score          6.819430
# imdb_votes      74137.774051
# dtype: float64
#
# Median:
# release_year     2017.0
# runtime            96.0
# seasons             2.0
# imdb_score          6.9
# imdb_votes      25306.5
# dtype: float64
#
# Percentage of Missing Values:
# id                       0.000000
# title                    0.000000
# type                     0.000000
# release_year             0.000000
# age_certification       20.822785
# runtime                  0.000000
# genres                   0.000000
# production_countries     0.000000
# seasons                 69.810127
# imdb_id                  0.000000
# imdb_score               0.000000
# imdb_votes               0.000000
# dtype: float64
#
# Unique Values in 'age_certification':
# <StringArray>
# [    'R',    'PG', 'TV-14',     'G', 'PG-13',     nan, 'TV-PG',  'TV-G',
#   'TV-Y', 'TV-Y7', 'TV-MA', 'NC-17']
# ...

# %%
import pandas as pd

#Loading clean dataframe:
df = pd.read_csv('C:\\Users\\pedro\\OneDrive\\Desktop\\Reccomendation_System\\movie-series-analysis\\data\\processed\\clean_titles.csv')

print("\nUnique Values in 'age_certification':")
print(df['age_certification'].unique())

print()
print(df['age_certification'].value_counts(normalize=True, dropna=False) * 100)
# Out:
# Unique Values in 'age_certification':
# <StringArray>
# [    'R',    'PG', 'TV-14',     'G', 'PG-13',     nan, 'TV-PG',  'TV-G',
#   'TV-Y', 'TV-Y7', 'TV-MA', 'NC-17']
# Length: 12, dtype: str
#
# age_certification
# R        24.810127
# NaN      20.822785
# TV-MA    17.911392
# PG-13    15.316456
# TV-14     8.670886
# PG        7.468354
# TV-PG     1.645570
# G         1.139241
# TV-Y7     0.822785
# TV-G      0.696203
# NC-17     0.569620
# TV-Y      0.126582
# Name: proportion, dtype: float64

# %%
import pandas as pd

#Loading clean dataframe:
df = pd.read_csv('C:\\Users\\pedro\\OneDrive\\Desktop\\Reccomendation_System\\movie-series-analysis\\data\\processed\\clean_titles.csv')

globalVotingMean = df['imdb_score'].mean()
print(f"Global Voting Mean: {globalVotingMean:.2f}")

minVotes = df['imdb_votes'].min()
print(f"Minimum Votes: {minVotes}")
# Out:
# Global Voting Mean: 6.82
# Minimum Votes: 7005

# %%
import pandas as pd

#Loading clean dataframe:
cleaned_df = pd.read_csv('C:\\Users\\pedro\\OneDrive\\Desktop\\Reccomendation_System\\movie-series-analysis\\data\\processed\\clean_titles.csv')

globalVotingMean = cleaned_df['imdb_score'].mean()
print(f"Global Voting Mean: {globalVotingMean:.2f}")

minVotes = cleaned_df['imdb_votes'].min()
print(f"Minimum Votes: {minVotes}")
# Out:
# Global Voting Mean: 6.82
# Minimum Votes: 7005
